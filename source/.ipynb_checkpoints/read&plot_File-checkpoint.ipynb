# %%
import uproot
import pandas
import matplotlib.pyplot as plt

# %%
f = uproot.open("/home/sebi/Documents/lxplus-stuff/QT_NN/Data//NN_full.root")
tree = f['Merged_Analysis;1']

# %%
tree.keys()
print(tree.keys())
# Out:
# [b'tot_vtx', b'Reco', b'Reco_z', b'Reco_tracks', b'Match', b'Match_z', b'Match_tracks', b'Merge', b'Merge_z', b'Merge_tracks', b'Split', b'Split_z', b'Split_tracks', b'Fake', b'Fake_z', b'Fake_tracks', b'ismerge']

# %%
diff = tree.pandas.df(["Match_z","Merge_z"])
diff_trk = tree.pandas.df(["Match_tracks","Merge_tracks"])

# %%
diff = diff.cumsum()
diff_trk = diff_trk.cumsum()

# %%
plt.figure("diff_vertex")

# %%
diff.plot()
diff_trk.plot()
